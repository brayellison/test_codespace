# %%
import pandas as pd
import numpy as np

pd.options.plotting.backend = "plotly"

# %%
x = np.random.normal(0, 1, 1000)
y = np.random.normal(x*2 + 5)

# %%
pd.DataFrame(
    np.vstack([x, y]).T,
    columns=['x', 'y']
).plot.scatter('x', 'y', height=600)
# Out:
# <div>                            <div id="547d9da3-95fa-4856-bd86-07663096afd3" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("547d9da3-95fa-4856-bd86-07663096afd3")) {                    Plotly.newPlot(                        "547d9da3-95fa-4856-bd86-07663096afd3",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.4202938282401323,1.1628168857559507,0.15439714697778895,-0.42025465038659104,1.0224176150682611,1.147490871849291,0.27806170265183927,-0.6726858564523933,0.6445727326438734,0.18287350223223392,1.7466372176268146,-1.3156227973894152,-0.13143916318230753,0.6456494209114214,0.213891
# ...
